# %% [markdown]
# # R Vignette
#
# This notebook uses the commands specified for dplyr databases vignette
# (https://cran.r-project.org/web/packages/dplyr/vignettes/databases.html)

# %%
#Load the libraries

library(dplyr)
library(nycflights13)
library(RSQLite)
# install.packages("RSQLite", dependencies=TRUE, repos='http://cran.us.r-project.org')

# %%
dim(flights)
#
# Out:
# [1] 336776     19

# %%
df <- tbl_df(flights)

# %%
head(df)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
nrows(df)
# Out:
# Error in eval(expr, envir, enclos): could not find function "nrows"
# Traceback:

# %%
filter(flights, month == 1, day == 1)
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013 1     1   517      515             2         830      819
# 2   2013 1     1   533      529             4         850      830
# 3   2013 1     1   542      540             2         923      850
# 4   2013 1     1   544      545            -1        1004     1022
# 5   2013 1     1   554      600            -6         812      837
# 6   2013 1     1   554      558            -4         740      728
# 7   2013 1     1   555      600            -5         913      854
# 8   2013 1     1   557      600            -3         709      723
# 9   2013 1     1   557      600            -3         838      846
# 10  2013 1     1   558      600            -2         753      745
# 11  2013 1     1   558      600            -2         849      851
# 12  2013 1     1   558      600            -2         853      856
# 13  2013 1     1   558      600            -2         924      917
# ...

# %%
arrange(flights, year, month, day)
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013 1     1   517      515             2         830      819
# 2      2013 1     1   533      529             4         850      830
# 3      2013 1     1   542      540             2         923      850
# 4      2013 1     1   544      545            -1        1004     1022
# 5      2013 1     1   554      600            -6         812      837
# 6      2013 1     1   554      558            -4         740      728
# 7      2013 1     1   555      600            -5         913      854
# 8      2013 1     1   557      600            -3         709      723
# 9      2013 1     1   557      600            -3         838      846
# 10     2013 1     1   558      600            -2         753      745
# 11     2013 1     1   558      600            -2         849      851
# 12     2013 1     1   558      600            -2         853      856
# ...

# %%
arrange(flights, desc(arr_delay))
# Out:
#        year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1      2013  1     9   641      900           1301      1242     1530
# 2      2013  6    15  1432     1935           1137      1607     2120
# 3      2013  1    10  1121     1635           1126      1239     1810
# 4      2013  9    20  1139     1845           1014      1457     2210
# 5      2013  7    22   845     1600           1005      1044     1815
# 6      2013  4    10  1100     1900            960      1342     2211
# 7      2013  3    17  2321      810            911       135     1020
# 8      2013  7    22  2257      759            898       121     1026
# 9      2013 12     5   756     1700            896      1058     2020
# 10     2013  5     3  1133     2055            878      1250     2215
# 11     2013 12    14   830     1845            825      1210     2154
# 12     2013  5    19   713     1700            853      1007     1955
# ...

# %%
somecolumns <- select(flights, year, month, day)

# %%
head(somecolumns)
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
distinct(flights, tailnum)
# Out:
#      tailnum
# 1    N14228
# 2    N24211
# 3    N619AA
# 4    N804JB
# 5    N668DN
# 6    N39463
# 7    N516JB
# 8    N829AS
# 9    N593JB
# 10   N3ALAA
# 11   N793JB
# 12   N657JB
# 13   N29129
# 14   N53441
# 15   N3DUAA
# 16   N708JB
# 17   N76515
# 18   N595JB
# 19   N542MQ
# 20   N644JB
# 21   N971DL
# 22   N730MQ
# 23   N633AA
# 24   N3739P
# 25   N53442
# 26   N9EAMQ
# 27   N532UA
# 28   N635JB
# 29   N794JB
# 30   N326NB
# ...  ...
# 4015 N152DL
# 4016 N790SK
# 4017 N843MH
# 4018 N797SK
# 4019 N762SK
# 4020 N933DN
# 4021 N768SK
# 4022 N795SK
# 4023 N780SK
# 4024 N143DA
# 4025 N740SK
# 4026 N726SK
# 4027 N705SK
# 4028 N728SK
# 4029 N824AS
# 4030 N702SK
# 4031 N560AS
# 4032 N778SK
# 4033 N922EV
# 4034 N710SK
# 4035 N647MQ
# 4036 N794SK
# 4037 N636WN
# 4038 N701SK
# 4039 N760SK
# 4040 N766SK
# 4041 N772SK
# 4042 N776SK
# 4043 N785SK
# 4044 N557AS

# %% [markdown]
# ## Getting started

# %%
my_db <- src_sqlite("my_db.sqlite3", create = T)

# %%
flights_sqlite <- copy_to(my_db, flights, temporary = FALSE, indexes = list(
  c("year", "month", "day"), "carrier", "tailnum"))
# Out:
# Error: Table flights already exists.
# Traceback:
#
# 1. copy_to(my_db, flights, temporary = FALSE, indexes = list(c("year",
#  .     "month", "day"), "carrier", "tailnum"))
# 2. copy_to.src_sql(my_db, flights, temporary = FALSE, indexes = list(c("year",
#  .     "month", "day"), "carrier", "tailnum"))
# 3. stop("Table ", name, " already exists.", call. = FALSE)

# %%
head(flights_sqlite)

# %%
flights_sqlite <- tbl(nycflights13_sqlite(), "flights")
# Out:
# Caching nycflights db at C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite
# Creating table: airlines
# Creating table: airports
# Creating table: flights
# Creating table: planes
# Creating table: weather

# %%
flights_sqlite
# Out:
# Source:   query [?? x 19]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
# 1   2013     1     1      517            515         2      830            819
# 2   2013     1     1      533            529         4      850            830
# 3   2013     1     1      542            540         2      923            850
# 4   2013     1     1      544            545        -1     1004           1022
# 5   2013     1     1      554            600        -6      812            837
# 6   2013     1     1      554            558        -4      740            728
# 7   2013     1     1      555            600        -5      913            854
# 8   2013     1     1      557            600        -3      709            723
# ...

# %%
tbl(my_db, sql("SELECT * FROM flights WHERE year=2013 and month = 2"))
# Out:
# Source:   query [?? x 19]
# Database: sqlite 3.11.1 [my_db.sqlite3]
#
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
# 1   2013     2     1      456            500        -4      652            648
# 2   2013     2     1      520            525        -5      816            820
# 3   2013     2     1      527            530        -3      837            829
# 4   2013     2     1      532            540        -8     1007           1017
# 5   2013     2     1      540            540         0      859            850
# 6   2013     2     1      552            600        -8      714            715
# 7   2013     2     1      552            600        -8      919            910
# 8   2013     2     1      552            600        -8      655            709
# 9   2013     2     1      553            600        -7      833            815
# ...

# %% [markdown]
# ## Basic Verbs

# %%
select(flights_sqlite, year:day, dep_delay, arr_delay)
# Out:
# Source:   query [?? x 5]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     year month   day dep_delay arr_delay
#    <int> <int> <int>     <dbl>     <dbl>
# 1   2013     1     1         2        11
# 2   2013     1     1         4        20
# 3   2013     1     1         2        33
# 4   2013     1     1        -1       -18
# 5   2013     1     1        -6       -25
# 6   2013     1     1        -4        12
# 7   2013     1     1        -5        19
# 8   2013     1     1        -3       -14
# 9   2013     1     1        -3        -8
# 10  2013     1     1        -2         8
# # ... with more rows

# %%
filter(flights_sqlite, dep_delay > 240)
# Out:
# Source:   query [?? x 19]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
# 1   2013     1     1      848           1835       853     1001           1950
# 2   2013     1     1     1815           1325       290     2120           1542
# 3   2013     1     1     1842           1422       260     1958           1535
# 4   2013     1     1     2115           1700       255     2330           1920
# 5   2013     1     1     2205           1720       285       46           2040
# 6   2013     1     1     2343           1724       379      314           1938
# 7   2013     1     2     1332            904       268     1616           1128
# 8   2013     1     2     1412            838       334     1710           1147
# ...

# %%
arrange(flights_sqlite, year, month, day)
# Out:
# Source:   query [?? x 19]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
# 1   2013     1     1      517            515         2      830            819
# 2   2013     1     1      533            529         4      850            830
# 3   2013     1     1      542            540         2      923            850
# 4   2013     1     1      544            545        -1     1004           1022
# 5   2013     1     1      554            600        -6      812            837
# 6   2013     1     1      554            558        -4      740            728
# 7   2013     1     1      555            600        -5      913            854
# 8   2013     1     1      557            600        -3      709            723
# ...

# %%
mutate(flights_sqlite, speed = air_time / distance)
# Out:
# Source:   query [?? x 20]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
# 1   2013     1     1      517            515         2      830            819
# 2   2013     1     1      533            529         4      850            830
# 3   2013     1     1      542            540         2      923            850
# 4   2013     1     1      544            545        -1     1004           1022
# 5   2013     1     1      554            600        -6      812            837
# 6   2013     1     1      554            558        -4      740            728
# 7   2013     1     1      555            600        -5      913            854
# 8   2013     1     1      557            600        -3      709            723
# ...

# %%
arrange(flights_sqlite, dep_delay, arr_delay)
# Out:
# Source:   query [?? x 19]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
# 1   2013     1     1       NA           1630        NA       NA           1815
# 2   2013     1     1       NA           1935        NA       NA           2240
# 3   2013     1     1       NA           1500        NA       NA           1825
# 4   2013     1     1       NA            600        NA       NA            901
# 5   2013     1     2       NA           1540        NA       NA           1747
# 6   2013     1     2       NA           1620        NA       NA           1746
# 7   2013     1     2       NA           1355        NA       NA           1459
# 8   2013     1     2       NA           1420        NA       NA           1644
# ...

# %%
summarise(flights_sqlite, delay = mean(dep_time))
# Out:
# Source:   query [?? x 1]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     delay
#     <dbl>
# 1 1349.11

# %% [markdown]
# ## Laziness

# %%
c1 <- filter(flights_sqlite, year == 2013, month == 1, day == 1)
c2 <- select(c1, year, month, day, carrier, dep_delay, air_time, distance)
c3 <- mutate(c2, speed = distance / air_time * 60)
c4 <- arrange(c3, year, month, day, carrier)

# %%
c3
# Out:
# Source:   query [?? x 8]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     year month   day carrier dep_delay air_time distance    speed
#    <int> <int> <int>   <chr>     <dbl>    <dbl>    <dbl>    <dbl>
# 1   2013     1     1      UA         2      227     1400 370.0441
# 2   2013     1     1      UA         4      227     1416 374.2731
# 3   2013     1     1      AA         2      160     1089 408.3750
# 4   2013     1     1      B6        -1      183     1576 516.7213
# 5   2013     1     1      DL        -6      116      762 394.1379
# 6   2013     1     1      UA        -4      150      719 287.6000
# 7   2013     1     1      B6        -5      158     1065 404.4304
# 8   2013     1     1      EV        -3       53      229 259.2453
# 9   2013     1     1      B6        -3      140      944 404.5714
# 10  2013     1     1      AA        -2      138      733 318.6957
# # ... with more rows

# %%
c4
# Out:
# Source:   query [?? x 8]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
#
#     year month   day carrier dep_delay air_time distance    speed
#    <int> <int> <int>   <chr>     <dbl>    <dbl>    <dbl>    <dbl>
# 1   2013     1     1      9E         0      189     1029 326.6667
# 2   2013     1     1      9E        -9       57      228 240.0000
# 3   2013     1     1      9E        -3       68      301 265.5882
# 4   2013     1     1      9E        -6       57      209 220.0000
# 5   2013     1     1      9E        -8       66      264 240.0000
# 6   2013     1     1      9E         0       40      184 276.0000
# 7   2013     1     1      9E         6      146      740 304.1096
# 8   2013     1     1      9E         0      139      665 287.0504
# 9   2013     1     1      9E        -8      150      765 306.0000
# 10  2013     1     1      9E        -6       41      187 273.6585
# # ... with more rows

# %%
collect(c4)
# Out:
#     year month day carrier dep_delay air_time distance speed
# 1   2013 1     1   9E        0       189      1029     326.6667
# 2   2013 1     1   9E       -9        57       228     240.0000
# 3   2013 1     1   9E       -3        68       301     265.5882
# 4   2013 1     1   9E       -6        57       209     220.0000
# 5   2013 1     1   9E       -8        66       264     240.0000
# 6   2013 1     1   9E        0        40       184     276.0000
# 7   2013 1     1   9E        6       146       740     304.1096
# 8   2013 1     1   9E        0       139       665     287.0504
# 9   2013 1     1   9E       -8       150       765     306.0000
# 10  2013 1     1   9E       -6        41       187     273.6585
# 11  2013 1     1   9E      -10        35        94     161.1429
# 12  2013 1     1   9E       52       173      1029     356.8786
# 13  2013 1     1   9E       88        72       427     355.8333
# 14  2013 1     1   9E       -4       107       509     285.4206
# ...

# %%
c4$query
# Out:
# NULL

# %%
explain(c4)
# Out:
# <SQL>
# SELECT *
# FROM (SELECT `year`, `month`, `day`, `carrier`, `dep_delay`, `air_time`, `distance`, `distance` / `air_time` * 60.0 AS `speed`
# FROM (SELECT `year` AS `year`, `month` AS `month`, `day` AS `day`, `carrier` AS `carrier`, `dep_delay` AS `dep_delay`, `air_time` AS `air_time`, `distance` AS `distance`
# FROM (SELECT *
# FROM `flights`
# WHERE ((`year` = 2013.0) AND (`month` = 1.0) AND (`day` = 1.0)))))
# ORDER BY `year`, `month`, `day`, `carrier`
#
#
# <PLAN>
#    addr       opcode p1    p2 p3           p4 p5 comment
# 1     0         Init  0    56  0              00      NA
# 2     1   SorterOpen  4     9  0       k(1,B) 00      NA
# 3     2     OpenRead  3   131  0           19 00      NA
# 4     3     OpenRead  5 22656  0     k(4,,,,) 02      NA
# 5     4         Real  0     1  0         2013 00      NA
# 6     5         Real  0     2  0            1 00      NA
# 7     6         Real  0     3  0            1 00      NA
# ...

# %% [markdown]
# ## SQL translation

# %%
translate_sql(x)
# Out:
# <SQL> "x"

# %%
translate_sql("x")
# Out:
# <SQL> 'x'

# %%
translate_sql("x")
# Out:
# <SQL> 'x'

# %%
translate_sql(x == 1 && (y < 2 || z > 3))
# Out:
# <SQL> "x" = 1.0 AND ("y" < 2.0 OR "z" > 3.0)

# %%
translate_sql(x ^ 2 < 10)
# Out:
# <SQL> POWER("x", 2.0) < 10.0

# %%
translate_sql(x %% 2 == 10)
# Out:
# <SQL> "x" % 2.0 = 10.0

# %% [markdown]
# ## Grouping

# %%
by_tailnum <- group_by(flights_sqlite, tailnum)

# %%
by_tailnum
# Out:
# Source:   query [?? x 19]
# Database: sqlite 3.11.1 [C:\Users\SIDDHA~1\AppData\Local\Temp\RtmpU7eFGQ/nycflights13.sqlite]
# Groups: tailnum
#
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
# 1   2013     1     1      517            515         2      830            819
# 2   2013     1     1      533            529         4      850            830
# 3   2013     1     1      542            540         2      923            850
# 4   2013     1     1      544            545        -1     1004           1022
# 5   2013     1     1      554            600        -6      812            837
# 6   2013     1     1      554            558        -4      740            728
# 7   2013     1     1      555            600        -5      913            854
# 8   2013     1     1      557            600        -3      709            723
# ...

# %%
delay <- summarise(by_tailnum,
  count = n(),
  dist = mean(distance),
  delay = mean(arr_delay)
)

# %%
delay <- filter(delay, count > 20, dist < 2000)

# %%
delay_local <- collect(delay)

# %%
delay_local
# Out:
#      tailnum count dist     delay
# 1    NA      2512  710.2576         NA
# 2    N0EGMQ   371  676.1887  9.9829545
# 3    N10156   153  757.9477 12.7172414
# 4    N102UW    48  535.8750  2.9375000
# 5    N103US    46  535.1957 -6.9347826
# 6    N104UW    47  535.2553  1.8043478
# 7    N10575   289  519.7024 20.6914498
# 8    N105UW    45  524.8444 -0.2666667
# 9    N107US    41  528.7073 -5.7317073
# 10   N108UW    60  534.5000 -1.2500000
# 11   N109UW    48  535.8750 -2.5208333
# 12   N110UW    40  535.3750  2.8000000
# 13   N11106   129  771.4109 14.8809524
# 14   N11107   148  705.8649 15.0143885
# 15   N11109   148  714.0000 14.8510638
# 16   N11113   138  719.7754 15.7619048
# 17   N11119   148  723.3851 30.3065693
# 18   N11121   154  719.3701 10.3061224
# 19   N11127   124  748.1129 13.6050420
# 20   N11137   112  726.5982 20.5514019
# 21   N11140   157  747.2102 18.3120567
# 22   N11150   136  775.5588  8.8914729
# 23   N11155    98  779.1224 12.9895833
# ...
